# %%
from elasticsearch import Elasticsearch
import pandas as pd
import numpy as np

# %%
es = Elasticsearch([
    "c18node2.acis.ufl.edu",
    "c18node6.acis.ufl.edu",
    "c18node10.acis.ufl.edu",
    "c18node12.acis.ufl.edu",
    "c18node14.acis.ufl.edu"
], sniff_on_start=False, sniff_on_connection_fail=False, retry_on_timeout=True, max_retries=10, timeout=10)

# %%
higher_taxon_ranks = ["dwc:kingdom","dwc:phylum","dwc:class","dwc:order","dwc:family"]

# %%
def rank_and_index(t):
    idx = t.Index
    if not isinstance(idx,tuple):
        idx=(idx,)
               
    rank = higher_taxon_ranks[len(idx) - 1]
    return (rank, idx)

# %%
def es_lookup(rank, idx):
    if idx[-1] == "":
        return ("", np.nan)    
    must = [
        {
            "match": {
                rank: {
                    "query": idx[-1],
                    "fuzziness": "AUTO"
                }
            }
        },
        {
            "term": {
                "dwc:taxonRank": rank.split(":")[-1]
            }
        }
    ]
    for i, r in enumerate(idx[:-1]):
        if r != "":
            must.append({
                "term": {
                    higher_taxon_ranks[i]: r
                }
            })
    hits = es.search(index="taxonnames",doc_type="taxonnames",body={
        "query": {
            "bool": {
                "must": must
            }
        }
    })["hits"]["hits"]  
    if len(hits) > 0:
        if "dwc:acceptedNameUsageID" in hits[0]["_source"]:
            hits = es.search(index="taxonnames",doc_type="taxonnames",body={
                "query": {
                    "bool": {
                        "must": {
                            "term": {
                                "dwc:taxonID": hits[0]["_source"]["dwc:acceptedNameUsageID"]
                            }
                        }
                    }
                }
            })["hits"]["hits"]
        if "gbif:canonicalName" in hits[0]["_source"]:
            name = hits[0]["_source"]["gbif:canonicalName"].lower()
        else:
            name = hits[0]["_source"]["dwc:scientificName"].lower()            
            
        return (name, hits[0]["_source"]["dwc:taxonID"])
    else:
        return ("", np.nan)

# %%
def higher_ranks(txid):
    hits = es.search(index="taxonnames",doc_type="taxonnames",body={
                "query": {
                    "bool": {
                        "must": {
                            "term": {
                                "dwc:taxonID": txid
                            }
                        }
                    }
                }
    })["hits"]["hits"]
    if len(hits) > 0:
        rank = "dwc:" + hits[0]["_source"]["dwc:taxonRank"]
        if "gbif:canonicalName" in hits[0]["_source"]:
            name = hits[0]["_source"]["gbif:canonicalName"].lower()
        else:
            name = hits[0]["_source"]["dwc:scientificName"].lower()
        
        if "dwc:parentNameUsageID" in hits[0]["_source"]:
            rv = higher_ranks(hits[0]["_source"]["dwc:parentNameUsageID"])
            if name != "":
                rv.update({rank: name, rank+"_id": hits[0]["_source"]["dwc:taxonID"]})
            return rv
        else:
            if name != "":
                return {rank: name, rank+"_id": hits[0]["_source"]["dwc:taxonID"]}
            else:
                return {}
    else:
        return {}

# %%
def correct_tree_frame(tree_frame):
    corrected_tree_frame = tree_frame.copy(deep=True)
    for cc in range(0, len(higher_taxon_ranks)):
        fields = list(higher_taxon_ranks[0:cc+1])
        print(fields)
        for t in corrected_tree_frame.groupby(fields).sum().itertuples():
            tv = True
            rank, idx = rank_and_index(t)
            if not isinstance(idx,tuple):
                idx=(idx,)
            
            tx, txid = es_lookup(rank, idx)
            
            for i, f in enumerate(fields):
                tv &= corrected_tree_frame[f] == idx[i]           

            if txid == txid and "" in idx:
                hr = higher_ranks(txid)
                for f, v in hr.items():
                    corrected_tree_frame.loc[tv, f] = v
            else:
                corrected_tree_frame.loc[tv, fields[-1]] = tx
                corrected_tree_frame.loc[tv, rank + "_id"] = txid

    return corrected_tree_frame

# %%
df = pd.read_csv("higherTaxon.csv", encoding="utf-8").fillna("")

# %%
df = df.sort_values("count", ascending=False)
df
# Out:
#       dwc:kingdom       dwc:phylum       dwc:class          dwc:order  \
# 54565
# 16662
# 18116
# 70278    animalia
# 49195
# 80637     plantae
# 9745
# 84125                                   gastropoda
# 14616
# 60875    animalia       arthropoda         insecta        hymenoptera
# 46826     plantae
# 46825     plantae                                           asterales
# 67293    animalia       arthropoda         insecta         coleoptera
# 19068     plantae    magnoliophyta                          asterales
# 82609     plantae                    dicotyledonae          asterales
# 81141     plantae
# 50605     plantae
# 53076
# 51573                     mollusca
# 26516
# 1980
# 9747
# 65306    animalia       arthropoda         insecta         coleoptera
# 61880
# 50607
# 39399     plantae
# 78104     plantae    magnoliophyta
# 3904      plantae                                              poales
# 4402
# 58888
# ...           ...              ...             ...                ...
# 55957                    crustacea                           decapoda
# 55958    animalia         annelida                       phyllodocida
# 55959                                     bivalvia           arcoidea
# 55960                      bryozoa                       cyclostomata
# 55961    animalia  platyhelminthes   rhabditophora
# 55962                                    crinoidea         comatulida
# 55963    animalia    echinodermata  cyclocystoidea       cyclocystida
# 55965    animalia       arthropoda       crustacea   decapoda caridea
# 55944                     animalia        reptilia         therapsida
# 55943                                   gastropoda         gastropoda
# 55942    animalia         mollusca      gastropoda    cocculiniformia
# 55941    animalia         chordata    osteichthyes  gasterosteiformes
# 55922    animalia       microspora
# 55923     plantae       rhodopyhta    rhodophyceae         gilidiales
# 55924     plantae     angiospermae   dicotyledonae            fabales
# 55926                                       fungos
# 55927     plantae        briophyta                          briophyta
# 55928     plantae
# 55929     plantae     angiospermas
# 55930                   arthropoda                        pycnogonida
# 55932     plantae      dicotyledon
# 55933
# 55934    animalia         chordata
# 55935    animalia         nematoda     adenophorea           plectida
# 55936                   arthropoda         insecta      raphidioptera
# 55937    animalia    echinodermata      stylophora     mitrocystitida
# 55938                                                      coleoptera
# 55939    animalia                     osteichthyes     anguilliformes
# 55940    animalia         chordata        reptilia    protorosauria ?
# 97818     plantae     angiospermas
#
#               dwc:family   count
# 54565                     546003
# 16662         asteraceae   70856
# 18116        orchidaceae   58703
# 70278                      46217
# 49195           fabaceae   44816
# 80637         asteraceae   44810
# 9745             poaceae   42260
# 84125                      39092
# 14616          rubiaceae   33861
# 60875         formicidae   33857
# 46826           fabaceae   33653
# 46825         compositae   30853
# 67293      staphylinidae   30456
# 19068         asteraceae   28224
# 82609         asteraceae   28055
# 81141            poaceae   27667
# 50605        orchidaceae   26871
# 53076          myrtaceae   26058
# 51573                      22921
# 26516         cyperaceae   21545
# 1980            rosaceae   21237
# 9747           lamiaceae   20979
# 65306          carabidae   20907
# 61880      euphorbiaceae   20528
# 50607           lichenes   19148
# 39399          rubiaceae   18763
# 78104         asteraceae   17931
# 3904           gramineae   17741
# 4402        pteridophyta   17613
# 58888         compositae   17536
# ...                  ...     ...
# 55957     camptandriidae       1
# 55958         alciopidae       1
# 55959            arcidae       1
# 55960  tretocycloeciidae       1
# 55961                          1
# 55962                          1
# 55963      cyclocystidae       1
# 55965       oplophoridae       1
# 55944   traversodontidae       1
# 55943        euconulidae       1
# 55942       cocculinidae       1
# 55941      fistulariidae       1
# 55922                          1
# 55923        gelidiaceae       1
# 55924           fabacene       1
# 55926       polyporaceae       1
# 55927          bryophyte       1
# 55928                 ae       1
# 55929          agavaceae       1
# 55930   callipallenidae?       1
# 55932      avicenniaceae       1
# 55933     caprifoliacaee       1
# 55934          camelidae       1
# 55935   diplopeltoididae       1
# 55936        raphidiidae       1
# 55937    mitrocystitidae       1
# 55938        scaphididae       1
# 55939          congridae       1
# 55940             undet.       1
# 97818          viscaceae       1
#
# [97819 rows x 6 columns]

# %%
cdf = correct_tree_frame(df)
ndf = df.copy(deep=True)
for c in cdf.columns:
    if c.endswith("_id"):
        ndf[c] = cdf[c]
    elif c == "count":
        pass
    else:
        ndf["new_" + c] = cdf[c]
# Out:
# ['dwc:kingdom']
# ['dwc:kingdom', 'dwc:phylum']
# ['dwc:kingdom', 'dwc:phylum', 'dwc:class']
# ['dwc:kingdom', 'dwc:phylum', 'dwc:class', 'dwc:order']
# ['dwc:kingdom', 'dwc:phylum', 'dwc:class', 'dwc:order', 'dwc:family']

# %%
re_agg = ndf.groupby([f for f in ndf.columns if f.startswith("new_") and f != "new_dwc:genus"]).sum()
re_agg.to_csv("tree_taxon.csv", header=True, encoding="utf-8")

# %%
ndf = ndf.sort_values([f for f in ndf.columns if f.startswith("new_")], ascending=False)
ndf
# Out:
#              dwc:kingdom                dwc:phylum           dwc:class  \
# 19046              virus
# 45229            viruses
# 90673
# 91238
# 69043
# 46615
# 6649            protista         sarcomastigophora
# 83970           protista         sarcomastigophora
# 16913           protozoa         sarcomastigophora    zoomastigophorea
# 83770           protista         sarcomastigophora
# 2295            protozoa         sarcomastigophora     zoomastigophora
# 67104
# 19049           protozoa         sarcomastigophora    zoomastigophorea
# 34029           protista         sarcomastigophora   granuloreticulosa
# 53563           protozoa              foraminifera
# 39156                                                       ebriediens
# 74917                                                       ebriediens
# 27165                                                       ebriediens
# 5096            protozoa         sarcomastigophora  phytomastigophorea
# 28751                                    see notes           see notes
# 62462           protista         sarcomastigophora   granuloreticulosa
# 50661           protista         sarcomastigophora   granuloreticulosa
# 9804            protista         sarcomastigophora
# 41890           protista         sarcomastigophora   granuloreticulosa
# 22991           protista         sarcomastigophora   granuloreticulosa
# 1625            protista         sarcomastigophora   granuloreticulosa
# 75737           protista         sarcomastigophora   granuloreticulosa
# 75296           protista         sarcomastigophora   granuloreticulosa
# 10891           protista         sarcomastigophora   granuloreticulosa
# 69920           protista         sarcomastigophora
# ...                  ...                       ...                 ...
# 53522
# 53550                                     hydroida
# 8156
# 54295                                                        crustacea
# 8197                                                        flagellata
# 56624
# 7720
# 7726
# 56755
# 56735
# 56413                                cooksonia sp.             plantae
# 56426
# 7743
# 7733            protista           bacillariophyta
# 55316
# 57110  geologic specimen              lignite coal
# 57177                                                     osteichthyes
# 57203
# 57021                                                 gymnospermopsida
# 7620
# 56896
# 55506
# 55373
# 55387
# 55360
# 55350           chordata                  reptilia
# 55441
# 55897        chlorobiota
# 55827
# 55845        ichnofossil  ichnofossil (vertebrate)          bird track
#
#              dwc:order               dwc:family  count new_dwc:kingdom  \
# 19046  mononegavirales            rhabdoviridae      1         viruses
# 45229     caudovirales               myoviridae      1         viruses
# 90673                                    fungus     18         viruses
# 91238                   uncertain fungus family      3         viruses
# 69043                      fungae-basidiomycota      1         viruses
# 46615                                    fungae      1         viruses
# 6649    trichomonadida       monocercomonadidae      1        protozoa
# 83970   trichomonadida          trichomonadidae      3        protozoa
# 16913    diplomonadida              hexamitidae     12        protozoa
# 83770    diplomonadida              hexamitidae      4        protozoa
# 2295     diplomonadida              hexamitidae      3        protozoa
# 67104                               hexamitidae      1        protozoa
# 19049    parabasalidea            cochlosomidae      1        protozoa
# 34029   foraminiferida             hormosinidae      1        protozoa
# 53563        lituolida             hormosinidae      1        protozoa
# 39156                                  ebriidae      7        protozoa
# 74917                             ditripodiidae     11        protozoa
# 27165                             ammodochiidae     13        protozoa
# 5096    dinoflagellida                oodinidae      1        protozoa
# 28751       see  notes            stereomyxidae      1        protozoa
# 62462   foraminiferida             nodosariidae     55        protozoa
# 50661   foraminiferida         lepidocyclinidae     49        protozoa
# 9804    kinetoplastida         trypanosomatidae     43        protozoa
# 41890   foraminiferida             nummulitidae     42        protozoa
# 22991   foraminiferida               nonionidae     41        protozoa
# 1625    foraminiferida               miliolidae     33        protozoa
# 75737   foraminiferida            vaginulinidae     32        protozoa
# 75296   foraminiferida           globigerinidae     30        protozoa
# 10891   foraminiferida          polymorphinidae     29        protozoa
# 69920        opalinida               opalinidae     29        protozoa
# ...                ...                      ...    ...             ...
# 53522                                 bryophyte      1
# 53550                                                1
# 8156                             caesalpinaceae      1
# 54295                                                1
# 8197    dinoflagellata            gonyaulacidae      1
# 56624                                        ni      1
# 7720                              rhodymeniales      1
# 7726                                      mixed      1
# 56755                       dialypetalanthaceae      1
# 56735                              steculiaceae      1
# 56413          plantae                               1
# 56426        thysanura   unidentified thysanura      1
# 7743                            actinopteraceae      1
# 7733                                     indet.      1
# 55316                             polypremaceae      1
# 57110                                                1
# 57177                                  otoliths      1
# 57203                             botryocarpeae      1
# 57021                                                1
# 7620                            lophothaliaceae      1
# 56896                                   cyperus      1
# 55506                             magnoliophyta      1
# 55373                              plectognathi      1
# 55387                       cryptogamic mixture      1
# 55360                         monocotylondoneae      1
# 55350       gekkonidae                 phelsuma      1
# 55441                          trebouxiophyceae      1
# 55897                                                1
# 55827                                2003-04-04      1
# 55845                                                1
#
#           new_dwc:phylum      new_dwc:class    new_dwc:order  \
# 19046                                        mononegavirales
# 45229                                           caudovirales
# 90673
# 91238
# 69043
# 46615
# 6649   sarcomastigophora    zoomastigophora   trichomonadida
# 83970  sarcomastigophora    zoomastigophora   trichomonadida
# 16913  sarcomastigophora    zoomastigophora    diplomonadida
# 83770  sarcomastigophora    zoomastigophora    diplomonadida
# 2295   sarcomastigophora    zoomastigophora    diplomonadida
# 67104  sarcomastigophora    zoomastigophora    diplomonadida
# 19049  sarcomastigophora    zoomastigophora
# 34029  sarcomastigophora  phytomastigophora          ebriida
# 53563  sarcomastigophora  phytomastigophora          ebriida
# 39156  sarcomastigophora  phytomastigophora          ebriida
# 74917  sarcomastigophora  phytomastigophora          ebriida
# 27165  sarcomastigophora  phytomastigophora          ebriida
# 5096   sarcomastigophora  phytomastigophora
# 28751  sarcomastigophora
# 62462  sarcomastigophora
# 50661  sarcomastigophora
# 9804   sarcomastigophora
# 41890  sarcomastigophora
# 22991  sarcomastigophora
# 1625   sarcomastigophora
# 75737  sarcomastigophora
# 75296  sarcomastigophora
# 10891  sarcomastigophora
# 69920  sarcomastigophora
# ...                  ...                ...              ...
# 53522
# 53550
# 8156
# 54295
# 8197
# 56624
# 7720
# 7726
# 56755
# 56735
# 56413
# 56426
# 7743
# 7733
# 55316
# 57110
# 57177
# 57203
# 57021
# 7620
# 56896
# 55506
# 55373
# 55387
# 55360
# 55350
# 55441
# 55897
# 55827
# 55845
#
#            new_dwc:family dwc:kingdom_id dwc:phylum_id dwc:class_id  \
# 19046       rhabdoviridae              8           NaN          NaN
# 45229          myoviridae              8           NaN          NaN
# 90673              fungal              8           NaN          NaN
# 91238              fungal              8           NaN          NaN
# 69043              fungal              8           NaN          NaN
# 46615              fungal              8           NaN          NaN
# 6649   monocercomonadidae              7            56          118
# 83970                                  7            56          118
# 16913         hexamitidae              7            56          118
# 83770         hexamitidae              7            56          118
# 2295          hexamitidae              7            56          118
# 67104         hexamitidae              7            56          118
# 19049       cochlosomidae              7            56          118
# 34029        hermesinidae              7            56          237
# 53563        hermesinidae              7            56          237
# 39156            ebriidae              7            56          237
# 74917       ditripodiidae              7            56          237
# 27165       ammodochiidae              7            56          237
# 5096                                   7            56          237
# 28751       stereomyxidae              7            56          NaN
# 62462                                  7            56          NaN
# 50661                                  7            56          NaN
# 9804                                   7            56          NaN
# 41890                                  7            56          NaN
# 22991                                  7            56          NaN
# 1625                                   7            56          NaN
# 75737                                  7            56          NaN
# 75296                                  7            56          NaN
# 10891                                  7            56          NaN
# 69920                                  7            56          NaN
# ...                   ...            ...           ...          ...
# 53522                                NaN           NaN          NaN
# 53550                                NaN           NaN          NaN
# 8156                                 NaN           NaN          NaN
# 54295                                NaN           NaN          NaN
# 8197                                 NaN           NaN          NaN
# 56624                                NaN           NaN          NaN
# 7720                                 NaN           NaN          NaN
# 7726                                 NaN           NaN          NaN
# 56755                                NaN           NaN          NaN
# 56735                                NaN           NaN          NaN
# 56413                                NaN           NaN          NaN
# 56426                                NaN           NaN          NaN
# 7743                                 NaN           NaN          NaN
# 7733                                 NaN           NaN          NaN
# 55316                                NaN           NaN          NaN
# 57110                                NaN           NaN          NaN
# 57177                                NaN           NaN          NaN
# 57203                                NaN           NaN          NaN
# 57021                                NaN           NaN          NaN
# 7620                                 NaN           NaN          NaN
# 56896                                NaN           NaN          NaN
# 55506                                NaN           NaN          NaN
# 55373                                NaN           NaN          NaN
# 55387                                NaN           NaN          NaN
# 55360                                NaN           NaN          NaN
# 55350                                NaN           NaN          NaN
# 55441                                NaN           NaN          NaN
# 55897                                NaN           NaN          NaN
# 55827                                NaN           NaN          NaN
# 55845                                NaN           NaN          NaN
#
#       dwc:order_id dwc:family_id
# 19046          842          7758
# 45229          843          3779
# 90673          NaN       4904189
# 91238          NaN       4904189
# 69043          NaN       4904189
# 46615          NaN       4904189
# 6649           875          2162
# 83970          875           NaN
# 16913          757          5858
# 83770          757          5858
# 2295           757          5858
# 67104          757          5858
# 19049          NaN       4906588
# 34029          758       3235208
# 53563          758       3235208
# 39156          758       4905122
# 74917          758       4905357
# 27165          758       3235213
# 5096           NaN           NaN
# 28751          NaN       4378578
# 62462          NaN           NaN
# 50661          NaN           NaN
# 9804           NaN           NaN
# 41890          NaN           NaN
# 22991          NaN           NaN
# 1625           NaN           NaN
# 75737          NaN           NaN
# 75296          NaN           NaN
# 10891          NaN           NaN
# 69920          NaN           NaN
# ...            ...           ...
# 53522          NaN           NaN
# 53550          NaN           NaN
# 8156           NaN           NaN
# 54295          NaN           NaN
# 8197           NaN           NaN
# 56624          NaN           NaN
# 7720           NaN           NaN
# 7726           NaN           NaN
# 56755          NaN           NaN
# 56735          NaN           NaN
# 56413          NaN           NaN
# 56426          NaN           NaN
# 7743           NaN           NaN
# 7733           NaN           NaN
# 55316          NaN           NaN
# 57110          NaN           NaN
# 57177          NaN           NaN
# 57203          NaN           NaN
# 57021          NaN           NaN
# 7620           NaN           NaN
# 56896          NaN           NaN
# 55506          NaN           NaN
# 55373          NaN           NaN
# 55387          NaN           NaN
# 55360          NaN           NaN
# 55350          NaN           NaN
# 55441          NaN           NaN
# 55897          NaN           NaN
# 55827          NaN           NaN
# 55845          NaN           NaN
#
# [97819 rows x 16 columns]

# %%
ndf.to_csv("tree_higherTaxon.csv", header=True, encoding="utf-8")

# %%
ndf[ndf["new_dwc:family"] == "agyrekocyathidae"]
# Out:
#       dwc:kingdom dwc:phylum      dwc:class        dwc:order  \
# 19801                         archaeocyatha  capsulocyathida
#
#              dwc:family  count new_dwc:kingdom new_dwc:phylum new_dwc:class  \
# 19801  agyrekocyathidae      2        animalia
#
#       new_dwc:order    new_dwc:family dwc:kingdom_id dwc:phylum_id  \
# 19801                agyrekocyathidae              1           NaN
#
#       dwc:class_id dwc:order_id dwc:family_id
# 19801          NaN          NaN       4814365

# %%
correct_tree_frame(df[df["dwc:family"] == "agyrekocyathidae"])
# Out:
# ['dwc:kingdom']
# ['dwc:kingdom', 'dwc:phylum']
# ['dwc:kingdom', 'dwc:phylum', 'dwc:class']
# ['dwc:kingdom', 'dwc:phylum', 'dwc:class', 'dwc:order']
# ['dwc:kingdom', 'dwc:phylum', 'dwc:class', 'dwc:order', 'dwc:family']
#       dwc:kingdom dwc:phylum dwc:class dwc:order        dwc:family  count  \
# 19801    animalia                                 agyrekocyathidae      2
#
#       dwc:kingdom_id  dwc:phylum_id  dwc:class_id  dwc:order_id dwc:family_id
# 19801              1            NaN           NaN           NaN       4814365

# %%
for f in ndf.columns:
    if "dwc:" in f and not f.endswith("_id"):
        print(f, len(ndf[f].unique()), ndf[ndf[f] == ""].shape[0]-1, ndf[ndf[f] == ""].sum()["count"])
# Out:
# (u'dwc:kingdom', 193, 33715, 2539369)
# (u'dwc:phylum', 1310, 33156, 3771171)
# (u'dwc:class', 1422, 43501, 4227414)
# (u'dwc:order', 4492, 30823, 3609477)
# (u'dwc:family', 24145, 4308, 932242)
# (u'new_dwc:kingdom', 10, 1664, 737336)
# (u'new_dwc:phylum', 84, 5298, 965205)
# (u'new_dwc:class', 238, 10258, 1134604)
# (u'new_dwc:order', 1108, 21719, 1416718)
# (u'new_dwc:family', 12545, 20775, 1526829)

# %%
re_agg.count()
# Out:
# count    13458
# dtype: int64
